# %% [markdown]
# # Stable Baselines3 - Train on Atari Games
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a collection of pre-trained Reinforcement Learning agents using Stable-Baselines3.
#
# It also provides basic scripts for training, evaluating agents, tuning hyperparameters and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !pip install stable-baselines3[extra] ale-py==0.7.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in c:\users\wb8by\appdata\roaming\python\python39\site-packages (1.7.0)
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp39-cp39-win_amd64.whl (904 kB)
#      ------------------------------------ 904.7/904.7 kB 147.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from ale-py==0.7.4) (1.19.5)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from ale-py==0.7.4) (4.13.0)
# Collecting importlib-resources
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: pandas in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (3.6.2)
# Requirement already satisfied: torch>=1.11 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: gym==0.21 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: cloudpickle in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: rich in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (12.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.11.2)
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: pillow in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (9.2.0)
# Requirement already satisfied: tqdm in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.56.0)
# Requirement already satisfied: psutil in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (5.9.4)
# Requirement already satisfied: opencv-python in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: click in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.3)
# Requirement already satisfied: requests in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.0.tar.gz (434 kB)
#      ------------------------------------ 434.7/434.7 kB 179.9 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: zipp>=0.5 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.10.0->ale-py==0.7.4) (3.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.15.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.36.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.6.3)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.34.1)
# Requirement already satisfied: filelock in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: networkx in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from torch>=1.11->stable-baselines3[extra]) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.0.1)
# Requirement already satisfied: sympy in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from torch>=1.11->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: typing-extensions in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (4.28.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from pandas->stable-baselines3[extra]) (2021.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (2.9.0)
# Requirement already satisfied: six in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from absl-py>=0.4->tensorboard>=2.9.1->stable-baselines3[extra]) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.5.30)
# Collecting libtorrent
#   Downloading libtorrent-2.0.7-cp39-cp39-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 731.0 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from jinja2->torch>=1.11->stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\wb8by\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.1)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): started
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.0-py3-none-any.whl size=446690 sha256=c90be5b6a4091205cc2250278c50bc8a80f650a30f00795aab4f8d05a4f00c92
#   Stored in directory: c:\users\wb8by\appdata\local\pip\cache\wheels\7d\17\c9\c31922a6aaf4ec7ec90eeee5dbc40ffbaafeda64b30a208b72
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: libtorrent, importlib-resources, AutoROM.accept-rom-license, autorom, ale-py
# Successfully installed AutoROM.accept-rom-license-0.6.0 ale-py-0.7.4 autorom-0.4.2 importlib-resources-5.12.0 libtorrent-2.0.7

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# %% [markdown]
# ## Training on Atari
#
# We will use atari wrapper (it will downsample the image and convert it to gray scale).
#
# About Atari preprocessing: [Frame Skipping and Pre-Processing for Deep Q-Networks on Atari 2600 Games](https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/)
#
# ![Pong](https://cdn-images-1.medium.com/max/800/1*UHYJE7lF8IDZS_U5SsAFUQ.gif)

# %%
# There already exists an environment generator that will make and wrap atari environments correctly.
env = make_atari_env('PongNoFrameskip-v4', n_envs=4, seed=0)
# Stack 4 frames
env = VecFrameStack(env, n_stack=4)

# %%
model = A2C('CnnPolicy', env, verbose=1)
model.learn(total_timesteps=10000)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------
# | time/                 |          |
# |    fps                | 304      |
# |    iterations         | 100      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | -0.00417 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.135   |
# |    value_loss         | 0.0935   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.35e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 310      |
# |    iterations         | 200      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.71    |
# |    explained_variance | 0.000917 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0199  |
# |    value_loss         | 0.0464   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.35e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 300      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | -0.00569 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.158   |
# |    value_loss         | 0.0899   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.38e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 400      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.0712   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0501   |
# |    value_loss         | 0.000932 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.41e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 500      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | -0.00161 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.182   |
# |    value_loss         | 0.101    |
# ------------------------------------

# %% [markdown]
# ## Download / Upload Trained Agent and Continue Training

# %% [markdown]
# Save and download trained model

# %%
#from google.colab import files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33328/2658820218.py in <module>
# ----> 1 from google.colab import files
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
model.save("a2c_pong")
#files.download("a2c_pong.zip")

# %% [markdown]
# Upload train agent from your local machine

# %%
#files.upload()

# %%
#!du -h a2c*

# %% [markdown]
# Load the agent, and then you can continue training

# %%
trained_model = A2C.load("a2c_pong", verbose=1)
env = make_atari_env('PongNoFrameskip-v4', n_envs=4, seed=0)
env = VecFrameStack(env, n_stack=4)
trained_model.set_env(env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
#trained_model.learn(int(0.5e6))
trained_model.learn(int(1.0e5))
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.46e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 100      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11848    |
# |    policy_loss        | -0.2     |
# |    value_loss         | 0.133    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.38e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 200      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11948    |
# |    policy_loss        | 0.0771   |
# |    value_loss         | 0.00233  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.5e+03  |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 300      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12048    |
# |    policy_loss        | 0.0561   |
# |    value_loss         | 0.00121  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.55e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 224      |
# |    iterations         | 400      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12148    |
# |    policy_loss        | 0.0546   |
# |    value_loss         | 0.00119  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.59e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 212      |
# |    iterations         | 500      |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12248    |
# |    policy_loss        | -0.13    |
# |    value_loss         | 0.093    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.59e+03  |
# |    ep_rew_mean        | -20.7     |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 600       |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 12348     |
# |    policy_loss        | -0.548    |
# |    value_loss         | 0.317     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.61e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 203      |
# |    iterations         | 700      |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12448    |
# |    policy_loss        | -0.259   |
# |    value_loss         | 0.179    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.61e+03  |
# |    ep_rew_mean        | -20.6     |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 800       |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 12548     |
# |    policy_loss        | 0.057     |
# |    value_loss         | 0.00147   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.58e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 202      |
# |    iterations         | 900      |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12648    |
# |    policy_loss        | 0.0449   |
# |    value_loss         | 0.000799 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.63e+03  |
# |    ep_rew_mean        | -20.5     |
# | time/                 |           |
# |    fps                | 198       |
# |    iterations         | 1000      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -1.74     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 12748     |
# |    policy_loss        | 0.0646    |
# |    value_loss         | 0.00169   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.65e+03  |
# |    ep_rew_mean        | -20.4     |
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 1100      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -1.73     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 12848     |
# |    policy_loss        | 0.0734    |
# |    value_loss         | 0.00235   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.65e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 1200     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12948    |
# |    policy_loss        | 0.0574   |
# |    value_loss         | 0.00137  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.73e+03  |
# |    ep_rew_mean        | -20.4     |
# | time/                 |           |
# |    fps                | 196       |
# |    iterations         | 1300      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 13048     |
# |    policy_loss        | -0.214    |
# |    value_loss         | 0.136     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 1400     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13148    |
# |    policy_loss        | -0.485   |
# |    value_loss         | 0.268    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.72e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 1500      |
# |    time_elapsed       | 151       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 13248     |
# |    policy_loss        | 0.057     |
# |    value_loss         | 0.00118   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 199      |
# |    iterations         | 1600     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13348    |
# |    policy_loss        | 0.0479   |
# |    value_loss         | 0.000881 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.75e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 1700      |
# |    time_elapsed       | 169       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 13448     |
# |    policy_loss        | -0.116    |
# |    value_loss         | 0.0916    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.72e+03  |
# |    ep_rew_mean        | -20.4     |
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 1800      |
# |    time_elapsed       | 178       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 13548     |
# |    policy_loss        | 0.0478    |
# |    value_loss         | 0.000891  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.72e+03  |
# |    ep_rew_mean        | -20.4     |
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 1900      |
# |    time_elapsed       | 188       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.74     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 13648     |
# |    policy_loss        | -0.234    |
# |    value_loss         | 0.178     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 199      |
# |    iterations         | 2000     |
# |    time_elapsed       | 200      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13748    |
# |    policy_loss        | -0.322   |
# |    value_loss         | 0.215    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.69e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 2100     |
# |    time_elapsed       | 212      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13848    |
# |    policy_loss        | 0.0852   |
# |    value_loss         | 0.00304  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.68e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 2200     |
# |    time_elapsed       | 223      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13948    |
# |    policy_loss        | -0.0362  |
# |    value_loss         | 0.0454   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.68e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 2300     |
# |    time_elapsed       | 234      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14048    |
# |    policy_loss        | -0.698   |
# |    value_loss         | 0.395    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 2400     |
# |    time_elapsed       | 245      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14148    |
# |    policy_loss        | 0.0647   |
# |    value_loss         | 0.00172  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 2500     |
# |    time_elapsed       | 255      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14248    |
# |    policy_loss        | 0.0721   |
# |    value_loss         | 0.00208  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 2600     |
# |    time_elapsed       | 265      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14348    |
# |    policy_loss        | -0.128   |
# |    value_loss         | 0.0902   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.71e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 195       |
# |    iterations         | 2700      |
# |    time_elapsed       | 276       |
# |    total_timesteps    | 54000     |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 14448     |
# |    policy_loss        | -0.618    |
# |    value_loss         | 0.35      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 2800     |
# |    time_elapsed       | 287      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14548    |
# |    policy_loss        | -0.464   |
# |    value_loss         | 0.267    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 2900     |
# |    time_elapsed       | 299      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14648    |
# |    policy_loss        | -0.121   |
# |    value_loss         | 0.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.74e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3000     |
# |    time_elapsed       | 309      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14748    |
# |    policy_loss        | -0.231   |
# |    value_loss         | 0.135    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.74e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 3100      |
# |    time_elapsed       | 320       |
# |    total_timesteps    | 62000     |
# | train/                |           |
# |    entropy_loss       | -1.75     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 14848     |
# |    policy_loss        | -0.349    |
# |    value_loss         | 0.217     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3200     |
# |    time_elapsed       | 330      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 14948    |
# |    policy_loss        | -0.205   |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3300     |
# |    time_elapsed       | 341      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15048    |
# |    policy_loss        | -0.093   |
# |    value_loss         | 0.0869   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3400     |
# |    time_elapsed       | 351      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15148    |
# |    policy_loss        | -0.432   |
# |    value_loss         | 0.255    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3500     |
# |    time_elapsed       | 361      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15248    |
# |    policy_loss        | -0.277   |
# |    value_loss         | 0.174    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3600     |
# |    time_elapsed       | 371      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15348    |
# |    policy_loss        | 0.0921   |
# |    value_loss         | 0.00344  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.73e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 3700      |
# |    time_elapsed       | 383       |
# |    total_timesteps    | 74000     |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 15448     |
# |    policy_loss        | 0.0849    |
# |    value_loss         | 0.00282   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.73e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 3800      |
# |    time_elapsed       | 393       |
# |    total_timesteps    | 76000     |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 15548     |
# |    policy_loss        | -0.11     |
# |    value_loss         | 0.0871    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 3900     |
# |    time_elapsed       | 403      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15648    |
# |    policy_loss        | 0.0802   |
# |    value_loss         | 0.00254  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.74e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 192      |
# |    iterations         | 4000     |
# |    time_elapsed       | 416      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15748    |
# |    policy_loss        | -0.124   |
# |    value_loss         | 0.0892   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.75e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 192      |
# |    iterations         | 4100     |
# |    time_elapsed       | 425      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 15848    |
# |    policy_loss        | 0.0674   |
# |    value_loss         | 0.00171  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.74e+03  |
# |    ep_rew_mean        | -20.3     |
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 4200      |
# |    time_elapsed       | 434       |
# |    total_timesteps    | 84000     |
# | train/                |           |
# |    entropy_loss       | -1.78     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 15948     |
# |    policy_loss        | 0.0649    |
# |    value_loss         | 0.00172   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 4300     |
# |    time_elapsed       | 442      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16048    |
# |    policy_loss        | -0.0375  |
# |    value_loss         | 0.0864   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 4400     |
# |    time_elapsed       | 450      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16148    |
# |    policy_loss        | 0.0912   |
# |    value_loss         | 0.00302  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 4500     |
# |    time_elapsed       | 459      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16248    |
# |    policy_loss        | 0.0925   |
# |    value_loss         | 0.00359  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 4600     |
# |    time_elapsed       | 468      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16348    |
# |    policy_loss        | -0.256   |
# |    value_loss         | 0.171    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.7e+03  |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 4700     |
# |    time_elapsed       | 477      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16448    |
# |    policy_loss        | 0.0972   |
# |    value_loss         | 0.0036   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 4800     |
# |    time_elapsed       | 487      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16548    |
# |    policy_loss        | -0.0803  |
# |    value_loss         | 0.0867   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 4900     |
# |    time_elapsed       | 497      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16648    |
# |    policy_loss        | 0.0848   |
# |    value_loss         | 0.00272  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 5000     |
# |    time_elapsed       | 505      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16748    |
# |    policy_loss        | -0.682   |
# |    value_loss         | 0.392    |
# ------------------------------------

# %%
trained_model.save("a2c_pong_3")
#files.download("a2c_pong_2.zip")
